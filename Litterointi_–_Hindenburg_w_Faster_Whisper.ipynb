# %% [markdown]
# <a href="https://colab.research.google.com/github/ollisulopuisto/hindenburg-helpers/blob/master/Litterointi_%E2%80%93_Hindenburg_w_Faster_Whisper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Jaksomedian litterointi Hindenburgia varten: Faster-Whisper v 2
#
# Luotu 6.3.2024. Pohjana Whisper for Podcasters v0.2 Oct 2, 2022 by [@UncannyRobot](https://twitter.com/UncannyRobot)

# %%
# @title Alusta litterointiympäristö
from IPython.display import clear_output
! apt install libcublas11
! pip install CTranslate2==4.5.0
# pip install --force-reinstall ctranslate2==3.24.0
# ! pip install git+https://github.com/federicotorrielli/BetterWhisperX

! pip install -U whisper-ctranslate2
from google.colab import drive
drive.mount('/content/drive')
# clear_output()
print('Valmista on, etiäpäin.')
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libcublas11 is already the newest version (11.7.4.6~11.5.1-1ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.
# Requirement already satisfied: CTranslate2==4.5.0 in /usr/local/lib/python3.11/dist-packages (4.5.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from CTranslate2==4.5.0) (75.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from CTranslate2==4.5.0) (2.0.2)
# Requirement already satisfied: pyyaml<7,>=5.3 in /usr/local/lib/python3.11/dist-packages (from CTranslate2==4.5.0) (6.0.2)
# Requirement already satisfied: whisper-ctranslate2 in /usr/local/lib/python3.11/dist-packages (0.5.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from whisper-ctranslate2) (2.0.2)
# Requirement already satisfied: faster-whisper>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from whisper-ctranslate2) (1.1.1)
# Requirement already satisfied: ctranslate2 in /usr/local/lib/python3.11/dist-packages (from whisper-ctranslate2) (4.5.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from whisper-ctranslate2) (4.67.1)
# Requirement already satisfied: sounddevice in /usr/local/lib/python3.11/dist-packages (from whisper-ctranslate2) (0.5.2)
# Requirement already satisfied: huggingface-hub>=0.13 in /usr/local/lib/python3.11/dist-packages (from faster-whisper>=1.1.1->whisper-ctranslate2) (0.33.0)
# Requirement already satisfied: tokenizers<1,>=0.13 in /usr/local/lib/python3.11/dist-packages (from faster-whisper>=1.1.1->whisper-ctranslate2) (0.21.1)
# Requirement already satisfied: onnxruntime<2,>=1.14 in /usr/local/lib/python3.11/dist-packages (from faster-whisper>=1.1.1->whisper-ctranslate2) (1.22.0)
# Requirement already satisfied: av>=11 in /usr/local/lib/python3.11/dist-packages (from faster-whisper>=1.1.1->whisper-ctranslate2) (14.4.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from ctranslate2->whisper-ctranslate2) (75.2.0)
# Requirement already satisfied: pyyaml<7,>=5.3 in /usr/local/lib/python3.11/dist-packages (from ctranslate2->whisper-ctranslate2) (6.0.2)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.11/dist-packages (from sounddevice->whisper-ctranslate2) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from CFFI>=1.0->sounddevice->whisper-ctranslate2) (2.22)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.13->faster-whisper>=1.1.1->whisper-ctranslate2) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.13->faster-whisper>=1.1.1->whisper-ctranslate2) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.13->faster-whisper>=1.1.1->whisper-ctranslate2) (24.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.13->faster-whisper>=1.1.1->whisper-ctranslate2) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.13->faster-whisper>=1.1.1->whisper-ctranslate2) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.13->faster-whisper>=1.1.1->whisper-ctranslate2) (1.1.3)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.11/dist-packages (from onnxruntime<2,>=1.14->faster-whisper>=1.1.1->whisper-ctranslate2) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime<2,>=1.14->faster-whisper>=1.1.1->whisper-ctranslate2) (25.2.10)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from onnxruntime<2,>=1.14->faster-whisper>=1.1.1->whisper-ctranslate2) (5.29.5)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from onnxruntime<2,>=1.14->faster-whisper>=1.1.1->whisper-ctranslate2) (1.13.1)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.11/dist-packages (from coloredlogs->onnxruntime<2,>=1.14->faster-whisper>=1.1.1->whisper-ctranslate2) (10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.13->faster-whisper>=1.1.1->whisper-ctranslate2) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.13->faster-whisper>=1.1.1->whisper-ctranslate2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.13->faster-whisper>=1.1.1->whisper-ctranslate2) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.13->faster-whisper>=1.1.1->whisper-ctranslate2) (2025.6.15)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->onnxruntime<2,>=1.14->faster-whisper>=1.1.1->whisper-ctranslate2) (1.3.0)
# Mounted at /content/drive
# Valmista on, etiäpäin.

# %%
# @title Muokkaa tähän oikeat kansiot.
input_dir = '/content/drive/MyDrive/whisper/input' # Drive-kansio, johon lataat käsiteltävät tiedostot
output_dir = '/content/drive/MyDrive/whisper/output/' # Drive-kansio, johon litteroinnit sisältävä .nhsx-tiedosto tallentuu

# %%
# @title Litteroi
# This is a Python script that reads all specified audio files in the input directory,
# uses Whisper to transcribe them into JSON files,
# then transforms the JSON timestamps into .nhsx XML format
# and inserts them in the .nhsx file

import os
import re
import json
from xml.etree import ElementTree

def hms_to_seconds(time_str):
    hours, minutes, seconds_milliseconds = time_str.split(':')
    seconds, milliseconds = seconds_milliseconds.split(',')
    return int(hours) * 3600 + int(minutes) * 60 + int(seconds) + float(milliseconds.replace(',', '.')) / 1000

def generate_srt_files(input_dir, output_dir):
    transcripts_dir = os.path.join(output_dir, 'transcripts')
    os.makedirs(transcripts_dir, exist_ok=True)

    audio_extensions = ('.wav', '.aiff', '.flac', '.m4a', '.mp4', '.mp3') # Added new extensions here

    # Recursive walk through all subdirectories
    for dirpath, dirnames, filenames in os.walk(input_dir):
        for filename in filenames:
            if filename.lower().endswith(audio_extensions): # Modified to check against tuple of extensions
                full_path = os.path.join(dirpath, filename)
                # Keep the filename's case. Just replace the audio extension with .json in lower case
                output_path = os.path.join(transcripts_dir, re.sub(r'\.(' + '|'.join(audio_extensions[0:]) + ')$', '.json', filename, flags=re.IGNORECASE))

                # Check if transcription already exists in .nhsx file
                if not is_file_already_transcribed(full_path, input_dir):
                    # If not transcribed, check if the JSON file exists
                    if not os.path.isfile(output_path):
                        print(f"Litteroidaan tiedostoa {full_path}")
                        # !whisper-ctranslate2 "{full_path}" --batched True --compute_type auto --word_timestamps True --max_line_width 33 --max_line_count 2  --vad_filter True --model turbo --language fi --output_dir "{transcripts_dir}"
                    else:
                        print(f"Ohitetaan tiedosto '{output_path}', koska se on jo olemassa.")
                else:
                    print(f"Ohitetaan tiedosto '{full_path}', koska se on jo litteroitu.")

def process_files(input_dir, output_dir):
    generate_srt_files(input_dir, output_dir)
    for filename in os.listdir(input_dir):
        if filename.lower().endswith(".nhsx"):
            with open(os.path.join(input_dir, filename), 'r') as f:
                nhsx_data = f.read()
            xml_elems = ElementTree.fromstring(nhsx_data)
            for session_elem in xml_elems:
                if 'AudioPool' in session_elem.tag:
                    for audio_pool_elem in session_elem:
                        if 'File' in audio_pool_elem.tag:
                            file_elem_name = audio_pool_elem.get('Name')
                            if file_elem_name:
                                # Modified to handle different audio extensions when creating srt_filename
                                audio_extensions_for_replace = ('.wav', '.aiff', '.flac', '.m4a', '.mp4')
                                srt_filename = file_elem_name # Removed .lower() here
                                for ext in audio_extensions_for_replace:
                                    if srt_filename.lower().endswith(ext): # Keep lower here for extension check
                                        srt_filename = srt_filename.replace(ext, '.json')
                                        break # Exit loop once replaced

                                transcripts_dir = os.path.join(output_dir, 'transcripts')
                                transcript_files = os.listdir(transcripts_dir)
                                # transcript_files_lower = [file.lower() for file in transcript_files] # Removed lowercasing
                                # if srt_filename in transcript_files_lower: # Changed the check
                                if srt_filename in transcript_files: # Case-sensitive check, or can be replaced with case-insensitive if needed
                                    # index = transcript_files_lower.index(srt_filename) # No longer needed
                                    # actual_srt_filename = transcript_files[index] # No longer needed
                                    actual_srt_filename = srt_filename # Filename should be directly matching now
                                    try:
                                        with open(os.path.join(transcripts_dir, actual_srt_filename), 'r') as f:
                                            srt_data = json.load(f)
                                    except FileNotFoundError:
                                        print(f"Tiedostoa ei löydy: '{srt_filename}'. Ohitetaan…")
                                        continue
                                else:
                                    print(f"No transcript found for '{srt_filename}'. Skipping...")
                                    continue # Skip this loop iteration if srt file wasn't found
                                transcription_elem = audio_pool_elem.find('Transcription')
                                if transcription_elem is not None:
                                    print(f"Tiedosto '{srt_filename}' on jo litteroitu, ei lisätä sitä.")
                                    continue
                                transcription_elem = ElementTree.SubElement(audio_pool_elem, 'Transcription')

                                p_elem = ElementTree.SubElement(transcription_elem, 'p')
                                for segment in srt_data['segments']:
                                    for word in segment['words']:
                                        sentence = word['word'].strip()
                                        start = word['start']
                                        end = word['end']
                                        word_elem = ElementTree.SubElement(p_elem, 'w')
                                        word_elem.set('l', str(end-start))
                                        word_elem.set('s', str(start))
                                        word_elem.set('sp', 'UU')
                                        word_elem.text = sentence

                                nhsx_tree = ElementTree.ElementTree(xml_elems)
                                output_filename = filename.replace('.nhsx', ' litteroitu.nhsx')
                                nhsx_tree.write(os.path.join(output_dir, output_filename), encoding='unicode')
                                print(f"Lisätään tekstitys '{srt_filename}' tiedostoon '{output_filename}'")
                            else:
                                print(f"No 'File' element found in {filename}. Skipping...")

def is_file_already_transcribed(wav_file_path, input_dir): # Function name is a bit misleading now as it handles more than wav
    """
    Checks if an audio file has already been transcribed by examining the corresponding .nhsx file.

    Args:
        wav_file_path (str): Path to the audio file.
        input_dir (str): Path to the directory containing the .nhsx files.

    Returns:
        bool: True if the file has been transcribed, False otherwise.
    """
    filename = os.path.basename(wav_file_path)
    nhsx_filename = filename.replace(os.path.splitext(filename)[1], '.nhsx', 1) # Replace extension with .nhsx
    nhsx_file_path = os.path.join(input_dir, nhsx_filename)

    if os.path.isfile(nhsx_file_path):
        with open(nhsx_file_path, 'r') as f:
            nhsx_data = f.read()
        xml_elems = ElementTree.fromstring(nhsx_data)
        for session_elem in xml_elems:
            if 'AudioPool' in session_elem.tag:
                for audio_pool_elem in session_elem:
                    if 'File' in audio_pool_elem.tag and audio_pool_elem.get('Name') == filename:
                        if audio_pool_elem.find('Transcription') is not None:
                            return True
    return False

process_files(input_dir, output_dir)
print("\nValmista tuli.")
# Out:
# Litteroidaan tiedostoa /content/drive/MyDrive/whisper/input/vst s10e06 - 2025-06-18 Files/Olli.wav
# model.bin:   0% 0.00/1.62G [00:00<?, ?B/s]
# config.json: 100% 2.26k/2.26k [00:00<00:00, 13.9MB/s]
#
# preprocessor_config.json: 100% 340/340 [00:00<00:00, 2.71MB/s]
#
# tokenizer.json:   0% 0.00/2.71M [00:00<?, ?B/s]
#
# model.bin:   1% 21.0M/1.62G [00:00<00:11, 140MB/s]
# tokenizer.json: 100% 2.71M/2.71M [00:00<00:00, 17.7MB/s]
#
#
# vocabulary.json: 100% 1.07M/1.07M [00:00<00:00, 7.29MB/s]
# model.bin: 100% 1.62G/1.62G [00:07<00:00, 204MB/s]
# Detected language 'Finnish' with probability 1.000000
# [00:45.380 --> 00:46.780]  ...
# [00:57.160 --> 01:25.660]  Niin, siis se silleen, että kun tökkäsin ekalla kerralla kiinni ulkoisen laitteen, niin virtavalo välähti. Sitten vaan silleen ihmettelin, että ei löydy mistään laitelistauksista, ja ajattelin, että se äänikortti oli luogisesti se asia, mikä meni rikki. Mutta onkin ilmeisesti. Kun sitä toi, ja siis tuossa on micro USB, niin toi porttihan on siis klähää, mutta... Anteeksi, siis ei edes USB-piuha, vaan USB-hubi. Se oli se kaikki omitys. Mulla on tämmöinen generni, joku Kiinahubi, mitä mä kyllä käyttänen. Niin, mutta siis...
# [01:25.680 --> 01:46.860]  Tämä on semmoinen, että tämä näkyy siellä laite-explorerissa, mutta jos mä laitan tähän perään USB-piuhanen äänekortin, niin ei näy, mutta jos laitan Applein oman hubin ja tässä mä laitan saman piuhan ja saman laitteen, niin toimii. Niin sitä mä en taju, että mikä se enää tavallaan laitetasolla... Mutta se on erikoinen...
# [01:49.970 --> 02:11.970]  Ei, ei, ja aina pitää olla pari. Mä hain jo toisen äänikortinkin, mutta se ei toiminut. Selkein vaihdan tätä hubia tässä. Onnittelut isoisälle, isoisyydestä. Et ole vanha, etkä pitää.
# [07:37.710 --> 08:02.350]  Hakijat. I will be right back. Mun täytyy myöntää, että mä jätin aurinkalaiset päähän se takia, että mä toivoin, että mä saan sinne alkuun jonkun muutaman sekunnin, mutta sit mä ajattelin, että jos Kari ei sanoo mitään laseista, niin Frozen, se että äänitys keskeytyy siihen, että menen hakemaan Frozen istuinkoroketta toimii. Mut joo, siis se, että se olisi musta niinku lähdetään siitä, että niiden aika on ohi.
# [08:02.570 --> 08:23.010]  Sitten voisi ehkä lyhyt historiikki tietenkin, että miten se alkoi ja minkä takia se ei enää toimi. Mulla on ainakin jotain bisnesmalliajatuksia, siis oli semmoinen vaihe, jolloin mietittiin, että notifikaatiot on se abstraktiokerros, jolla toimitaan älypuhelimissa. Tavallaan sovelluksella ei ole niin paljon väliä, koska saadaan käyttäjän huomioon notifikaation kautta ja sehän kilpailtiin kuoliaksi tavallaan välittömästi.
# [08:32.400 --> 08:58.100]  Joo, loistavaa, hyvä. Mutta ehkä sitten se, että varmaan voisi tehdä silleen, että jos aloittaisiin, että niiden aika on ohi, sitten vähän jossain määrin kronologisesti, ja lopussa sitten, että okei, no mitä tästä seuraa, että mä sanoisin, että se olisi rakenne, mutta tulen ihan pian takaisin. Tämä ei kuulu suunnitelmaa. Tämä möläys.
# [14:13.130 --> 14:35.770]  En löytänyt laseja alakerrasta. Edelleen mennään vauhdikkailla laseilla. Oli ne vielä aamulla tallessa. Ratkaisitteko tällä väliä kaikki ongelmat? Myös jakson rakenteeseen liittyvät.
# [14:45.270 --> 14:55.590]  Ei pidä paikkaansa. Panu on jäänyt tekstianalyysissa selvästi 89-luvulla. Aina kun viitataan siihen, niin se on tosi täpinöissä.
# [15:13.680 --> 15:37.760]  Hyvä. Mä oon silleen kesämeiningissä tässä joka tapauksessa, siis silleen podcastia tehdään löysin ranteen, mutta I have a cunning plan. Mikä oli siis, tästä oli tossa Suomen Kuvalehden podcastissa, kun siis se Naton kuka ikinä pääsihteeri selittää niitä budjettitavoitteita, että tulee 3,5 plus 1,5 ja sitten kysyttiin, että no miten kun aiemminkin on tehty suunnitelmia, että...
# [15:37.600 --> 16:03.120]  että pitäisi nostaa, ja sitten jäsenvaltiot eivät ole sitoutuneet, että se oikeasti vastaisi aloittamaan, että I have a cunning plan. Ja siis ne huomauttaa siinä podcastissa, että kai tämä oli nyt tarkoituksellinen viittaus, mutta jos olisi tavallaan kansainvälisen puolustusliiton johtavassa asemassa, ja sitten sieltä kysytään, että kun aiemmin tämä sama homma meni syteen, niin miten se... Mä en tiedä, että olisiko se sellainen kuin kummelisitaatti alkuun siinä tavallaan toimiva ratkaisu, että...
# [16:07.980 --> 16:11.100]  Niin ehkä. Joo.
# [26:55.340 --> 27:23.120]  Minun sovellukseni olisi hirmu hyvä, että minun sovellukseni saisi huomiota käyttäjätä, että minun sovellukseni lähettää sinne ilmoituksen, ja sehän voi olla oikein kiva. Mutta joka ikinen sovellus ajattelee samalla tavalla, eikä ne ole tietoisia siitä, mitä ne muut sovellukset tekee, joka siis johtaa sitten tähän, että sen jälkeen niitä ilmoituksia tulee ihan hirveästi, ja sitten siitä alkaa semmoinen evolutiivinen kilpajuoksu, että okei, no käyttäjä ei huomannut tätä mun ilmoitusta, että pitääpä lähettää sille uudestaan ilmoitus. Ja mun mielestä se on peli, jota ei voi voittaa, ja sen takia mä oonkin nyt tämän...
# [27:23.080 --> 27:27.280]  ilmoituksen jälkeisen ajan sanansaattaja, airut ja julistaja.
# [29:12.880 --> 29:41.760]  Ja siis tämähän on samalla tavalla Applella ollut se, että se oli yksi niistä Apple AI-paraatiesimerkeistä, että hei, että sen sijaan, että joutuisit itse katsomaan maaorjan tavoin, mitä tässä ilmoituksessa lukee, niin Siri tässä tiivistää se sinulle, ja sitä se ainakin toimii päin helvettiä aina kaikissa demoissa jotenkin, että kiireellinen viesti äidiltä tyyppisiä tiivistelmiä. Mutta mulla on kaksi pointtia tästä, joista ensimmäinen on se, että kaikki toi käyttiksen tasolla.
# [29:42.520 --> 30:05.620]  tapahtuva. Oli se sitten niin kuin, no mulla on MacOS-läppärissä, niin siinähän on kanssa ilmoituskeskus. Ja se oli iso muutos. Aiemmin oli Growl-niminen lisäosa, siis jälleen vitsi mä oon vanha, siitä on kohta 20 vuotta. Mutta tavallaan se oli tuskasta, kun siirryttiin Growlista tohon Mäkin keskitettyyn järjestelmään, koska se on muun muassa käyttöliittymällisesti edelleen semmoinen outo homma, että Descarilla, Mäkillä ei voi helposti kuidata kaikkia ilmoituksia luetuksi.
# [30:06.630 --> 30:35.310]  Sitten kun siellä on esimerkiksi lapseni, kun lähettää minulle peliaikapyyntöä, niin te voi olla pikkaan 20 kertaa sitä pientä ruksia, joka ilmestyy vaan, kun hiiren laittaa oikean kohtaan siinä ikkunassa. Ja vaikka se käli olisi tosi hyvä siinä, vaikka se olisi hirmusujuva käyttää, niin silti se on mun mielestä selkeästi. Se on siis ambulanssikuilun pohjalla. Se on laastari, joka laitetaan sen jälkeen, kun se haava on tullut. Se ei siis millään voi poistaa sitä ongelmaa. Ja toinen pointti on se, että kun mä sanon, että ilmoituksien aika, eli ilmoituksien aikakausi on ohi,
# [30:35.680 --> 31:03.320]  niin se ei ole vitsi, vaan mä viittaan siihen, että missä tahansa uudessa ominaisuudessa nimenomaan on, niin että alussa siellä on enemmän tilaa. Siis on tavallaan enemmän voitettavaa, koska on vähemmän kilpailijoita mukana siinä. Että sehän näkyy muutenkin, jos katsoo vaikka jotain sosiaalisen median palveluita, että kun tulee uusi palvelu, niin jos oot ensimmäisiä, jotka rupee sinne luomaan köntsää, niin on mahdollista luultavasti saada sillä samalla toiminnalla enemmän seuraajia, kun on mahdollista saada, jos liityt mukaan vuotta, kahta, kolmea vuotta myöhemmin, koska silloin siellä on jo enemmän tarjontaa. Että se on ihan loogista.
# [31:03.680 --> 31:22.980]  että tämmöinen juttu, jossa kilpaailaan käyttäjien huomioista toimii ajan hetkellä nolla eri tavalla kuin ajan hetkellä viisi vuotta. Ja siksi myös musta tuntuu, että se nykymallinen, just nimenomaan älypuhelimissa, mutta myös pöytäkoneissa näkyvä ilmoitushomma, niin se on vaan pakko jotenkin polttaa maan tasalle ja keksiä siihen tilalle jotain uutta.
# [31:36.300 --> 31:37.100]  Niin ja vähän.
# [31:50.220 --> 32:18.620]  No siis mä nopeasti katoin, mä avasin mun kännykän tästä, niin tänään, ja siis kesäkuu, eli mä oon periaatteessa lomalla, niin mun kännykässä on 239 ilmoitusta tullut tänään, kello kuuteen mennessä päivällä, joista puolet on WhatsAppia. Pikaviestimiä on valtaosa tästä, mutta silti, että voi miettiä, että jos mä oon herännyt, no okei, tänään mä joudun heräämään vähän aikaisemmin, mutta sanotaan pyöreästi, että mä oon ollut 10 tuntia hereillä, ja mulle on tullut 240 ilmoitusta. Eli siis...
# [32:18.560 --> 32:29.520]  joka toinen, kahden puolen minuutin välein ilmoitus. Se on ihan selvä, että semmoinen äärasyk, että ei tietenkään siihen voi reagoida. Ei ole mitään tapaa, ei niitä voi ryhmitellä mitenkään silleen, että mä voisin reagoida 250 kertaa jotenkin niihin.
# [33:01.340 --> 33:21.220]  Mä en siis just kysyä tässä, että... Mutta eikö tässä tulla semmoiseen siis käyttöliittymälliseen tai käyttökokemukselliseen ongelmaan, että miten se sun puhelimes, joko käyttöliittymä tai se sovellus tai vaikka se viestin lähettäjä voi tietää, että A, tämä on oikeasti kiireellinen viesti tai B, että kilpailu...
# [33:21.820 --> 33:34.680]  että kilpaileeko se sun huomiosta oikealla hetkellä. Mun mielestä tämä, siis sä oot oikein siinä, että selvästi aikakriittisyys on asia, jossa on semmoinen, että olisi hyvä, että tulee ilmoitus, mutta eikö toi johda vaan siihen, että kaikki rupeaiset merkkaamaan, että no tää on ykkösprioriteetin viesti ja tää on kaikkein kiireellisintä.
# [34:46.240 --> 34:47.620]  Mut jalo on villi.
# [35:36.670 --> 36:05.010]  Mutta eikö tuossa ole ihan sama ilmiö, että se tullaan kilpailemaan nollaan? Siis mä otan vähän rinnakkaisen esimerkin, joka on se, että Whatsappissa ja monessa muussakin pikaviestimessä voi kiinnittää tietyt keskustelut ruudun yläreunaan, kun normaalisti on niin, että ruudun yläreunaan pompahtaa jutut, joista on tullut viimeisimmäksi viesti. Ja sit mäkin jossain vaiheessa ajattelin, että no okei, että varsinkin kun mä käytän Bieberia, joka siis tuo tosiaan monta viestintä saman ohjelman alle tässä työpöydällä, niin se oli silleen, että no okei, mulla on ehkä jokaisessa näistä erillisistä...
# [36:04.990 --> 36:26.970]  viidestä viestimestä yksi tai kaksi tärkeää keskustelua. Minulla on oikeasti sellainen, että minulla on seitsemän pinnat tuo keskustelu, ja siinä vaiheessa voi miettiä, että jos minulla on seitsemän tärkeintä asiaa, niin ei tämä oikein toimi. Siis käyttöliittymän metaforan tuossa on erilainen, puhutaan siitä, että miten jaetaan ruutupinta-alaa, mutta kun niitä tärkeitä asioita alkaa olla yli yksi, ja se on jatkuvasti tärkeäksi merkitty, niin jälleen se arvo hajoaa.
# [37:11.230 --> 37:14.270]  Taas komponistinen vallankumous huudettu.
# [38:04.210 --> 38:32.790]  Mutta eikö tuossakin tule ongelmaksi? Se ei ole ihan sama ongelma, mutta se on ehkä se, että jos käyttäjän pitää erikseen kertoa tietokoneelle ja tietokoneohjelmalle, että nyt minua saa häiritä, nyt ei saa häiritä, niin se on hankala. Se asettaa siis kognitiivista taakkaa. Sitten tulee heti semmoinen olo, että no ehkä pitäisi olla useampi porsto, että päästä ykkösprioriteetin viestit läpi, päästä kakkosprioriteetin läpi. Ja tässä vaiheessa sulla tulee olemaan, että sitten on semmoinen valintakytki, jossa on viisi eri asiaa, ja eihän sitä itsekään kohta muista, miten se toimii.
# [38:33.000 --> 39:00.560]  joka siis tavallaan ajaa painoa sille, että okei, no etenkin älypuhelin tietää tosi hyvin, mitä tapahtuu, siinä on paikkasignaali, se näkee, mitä sovelluksia on käytössä. Ja siis kyllähän iOS-assakin, mullakin esimerkiksi siinä on sellainen työtila, joka toimii ihan päin bylyä, siis koska se käyttää just jotain aika karkeita signaaleja paikka ja aika. Ja sitten mä aina välillä vaan huomaa, että mulla on eri ikonit kotiruudulla, koska se on päättänyt, että mä oon jossain työskentelytilassa. Tai esimerkiksi tämmöinen asia, että kun mä oon lomalla nyt periaatteessa, niin en minä lue mistään kalenterista.
# [39:00.650 --> 39:04.490]  Sinä olet lomaa, sinä olet töissä. Nyt on maanantai ja kello on yhden mennyt sinä olet töissä.
# [39:42.960 --> 40:08.760]  Just näin. Just näin. Siis mä kyselin tässä ennen äänitystä tuolla Interin netseissä, että minkälaisia suhteita ihmisillä on ilmoituksin. Tämä kuulostakin todella omituiselta, mutta pointtinen siinä, että mä yritin esittää avoimmin kysymyksen, että en ikään kuin silleen sitä, vihaatko sinäkin ilmoituksia, koska välillä sellaiset jotenkin postaukset menee hyvin läpi. Mutta siis siellä tuli tämmöisiä mielestäni just...
# [40:08.710 --> 40:36.170]  teemaan sopivia pointteja, eli aika moni sanoo esimerkiksi, että perheen tai ystävien viestit tulee jotenkin läpi, että se on selvästi sellainen tietyt ihmiset aina, mihin mä oon tässä viitattu, mutta siinäkin on, kuten Kari sanoit, niin välillä se on vähän tyhmä filteri, esimerkiksi nyt kun mä äänetän podcastia ja vaimo soittaa, niin sitten mä olin silleen, että vaimo ei saa nyt soittaa, mutta eipä tiennyt tietokone sitä. Ja toinen oli sitten taas jälleen toi kontekstitieto ajan perusteella, että yksi ihminen sanoi, että hän käyttää erillistä työläppäriä,
# [40:36.350 --> 41:01.770]  Tai siis tavallaan se, että on erillinen työläppäri, huolehtii siitä, että se saa piipata ihan rauhassa, koska se on auki silloin, kun on työaika. Niin tietyllä tavalla, että silloin on fine kilpailla huomiosta, koska sitten se laittaa sen kiinni kello 17, ja sen jälkeen tämä fyysinen affordanssi, että läpsäyttää kannen kiinni, ja siitä ei enää tule piippauksia toimia. Mutta panurädyllä on eettämättä useita laitteita, josta voit avata yhden sitä varten, kun sä oot joogaamassa, ja se piippaa joogapiippauksia.
# [41:05.310 --> 41:16.290]  Siis sehän on Lenovon tuotelinja, että äläpä siellä yhtään vitsaile. Se on se tablettiläppäri. No, totta kai sä tiedät. Juuri näin.
# [41:59.490 --> 42:22.930]  Kyllä, koska siinä varmaan tosi nopeasti tulisi uncanny väli, eli unheimlich, ja mä en tiedä mitä laakso on saksaks, joten sitä mä en aio lausua. Mutta siis tavallaan tämä unheimlich tal, hyvä. Mutta siis ikään kuin, että tiedätkö, jos on tosi karkeat portaat, kaikki ilmoitukset päällä, kaikki ilmoitukset pois päällä, niin se on helppo ymmärtää ja tavallaan tietää, että mä nyt menetän tässä jotain, että ehkä osa ilmoituksista olisi hyödyllisiä, mutta mä oon muuttanut...
# [42:22.760 --> 42:44.180]  tosi isosti sitä toimintaa. Ja sitten, että jos siellä on tietty määrä automaatiota, niin ainakin mulla se menee helposti sille, että mua alkaa ärsyttää se, kun se toimii väärin paljon enemmän, niin kuin false-positiivet ja muut. Että tavallaan siinä on inhottava sellainen paradoksuaalinen suhde, että mitä tarkempi, hienojakoisempi, automatisoidumpi systeemi se on, niin sitä enemmän mua ärsyttää, kun se automaatio tekee virheitä.
# [43:20.960 --> 43:41.980]  Ja sitten se viesti jotenkin, että seuraavasi OnlyFans-tili on julkaissut uutta sisältöä. Ja tossahan siihen tullaankin. Tämä on vähän semmoinen, että erinäköiset virtuaaliavustajat oli kanssa jossain vaiheessa suurta huutoa, ja käytännössä kai ne parhaiten toimivat oli oikeasti vaan Filippiinillä olevia alipalkattuja ihmisiä, että amerikkalaiset pystyivät ulkoistamaan ne niille.
# [43:45.550 --> 44:12.570]  Periaatteessa yksinkertainen tehtävä, mutta itse asiassa sitten tosi monimutkainen, inhottava tehtävä, jossa tulee tosiaan niitä false positiveja. Mä jatkan ihan vielä vähän siteraan täältä viisauksia. Oli kiinnostava Rasmus Vuori, joka on siis muistaakseni Aalto-yliopistossa töissä, sanoi, että sillä on semmoinen jännittävä tilanne, että hän käyttää omaa puhelinta työpuhelimessa, koska se, joka on tullut firmalta ja jossa on toisinsaattuna keskitetty ylläpito,
# [44:12.920 --> 44:41.000]  niin se on niin locked down, että se ei pysty säätämään siitä notifikaatioasetuksia. Ja mä en tiedä, että onko tämä tavallaan vain sitten sen keskitytyn hallinnan ikään kuin ominaisuus siinä mielessä, että ne ei vaan halua miettiä sitä, että annetaanko me käyttäjän säätää ominaisuuksia, vai eikö siellä ole semmoista tarkkuutta, että voisi sanoa, että no okei, notifikaatioasetuksiin pääset näppäilemään. Mutta kun tosiaan tällaisia kaiken näköisiä rajatapauksia alkaa tulla tuolla vastaan, niin kyllähän tässä ihminen vähän ei rupea käsiä heittämään pois. Ja sitten tosi moni sanoo,
# [44:41.240 --> 45:04.600]  Siis, että oli joku versio siitä, että on vähän niin kuin silleen fuck it all, että tulee ilmoituksia, siis mä välillä vaan niin kuin katson ne, mutta siis nimenomaan, että en lue läpi, en edes kimmaa, vaan oikeastaan vaan niin kuin on hyväksynyt sen, että tulee monta notifikaatiota ja sitten heitän ne pois. Ja mulle tulee tästä mieleen sellaiset sivistymättömät ihmiset, jotka eivät organisoi tiedostojaan hierarkisesti. Olemme ja kuulee, että tässäkin podcastissa eräästä sellaisesta...
# [45:04.880 --> 45:24.020]  tai jotka ei järkkää sähköpostiin inboxia, ja sitten ne on silleen, että niillä on oikeasti jotain satatuhatta lukematonta viestiä inboxissa, ja siinä on niin paljon väärää, siinä on niin paljon väärää, siis ensinnäkin on olemassa suodattimia, ne voi laittaa alikansioihin, ne voi merkitä luetuiksi. Ei, ei, ei voi.
# [46:15.440 --> 46:44.020]  Toi pankkikorttihomma on muuten hankala. Mä just vääsin kännykässä Apple Wallettiin sen päälle, kun oltiin reissun päällä. Ja sitten siinä tulee esimerkiksi tämmöinen hyvin suomalainen ongelma, että kun asioin Prismassa ja ostan jotain, niin S-mobiilisovellus lähettää mulle ilmoituksen, että tässä on kuittisi ja samaan aikaan siis Apple Wallet lähettää. Tavallaan kaksi eri asiaa triggeröisin. Toinen tulee sieltä kassajärjestelmästä, että tulee kuittidata ja toinen on maksutransaktio. Mutta lopputulos on se, että käytännössä mulla on samasta asiasta kaksi ilmoitusta ruudulla.
# [46:44.350 --> 47:09.510]  Ja mä voisin vääntää kokonaan sitten se S-Koratin ilmoitukset pois päältä, mutta entä jos joku kavaltaa sen ja ostaa OnlyFansin, koska se ei ole vielä SOKn hallussa, niin siitä ei tulisi mulle ilmoitusta S-Mobiilin kautta. S-Mobiili muuten, no niin nyt, herranjumala, oi oi oi, hirvittävän huono vitsi, hirvittävän huono vitsi. Mutta lisäksi, kun sanoit, tai viittasimme tähän sähköpostiin, niin musta jälleen jos ottaa...
# [47:09.450 --> 47:25.170]  analogisen askeleen sivulle, että kyse ei ole tosiaan pelkästään ilmoituksista, vaan kyse on käyttäjän huomiosta kilpailemisesta, ja jos katsoo, että mitä Gmail teki, webin Gmail jo vuosia sitten, oli se, että nehän laittoi oletusarvosti päälle automaattisen suodattamisen, ja sitten sinne tulee just silleen, että tässä on...
# [47:25.360 --> 47:54.220]  Onko nyt promootiot? Mä en nimittäin käytä sitä. Mulla on tietenkin vain hienoimmat käsinrakennetut filterit itselläni käytössä, että mä en mitään automaattifilttereitä käytä. Mutta sehän johtaa siihen samaan asiaan, että sitten substack-kaita on aina silleen, että hei, nyt kun olet tilannut tämän sähköpostin, niin tämä voi hyvin helposti mennä spämmiin, että käypä muuten katsomassa erikseen spämmifolderista ja flaggaa se normaaliksi mailiksi. Tai jälleen osoittaakseni, että kyse ei ole pelkästään ilmoituksista vaikka onkin, niin jos miettii mitä tubettajat tekee.
# [47:54.720 --> 48:21.260]  niin tubettajathan ihan maneeristi sanoo aina silleen, että A, käy tilaamassa tämä kanava, jos sitä ei ole tilannut, ja B, laita ilmoitukset päälle. Ja nyt lapset, mitä opimme äsken yhteisman tragediasta? Jos kaikki käyttäjät laittaisivat kaikista tilaamistaan kanavista ilmoitukset päälle, niin lopputulos on se, että se on ihan sama kuin kenelläkään ei olisi ilmoitukset päällä mistään kanavasta. Siinä ei ole semmoista tasapainotilannetta, jossa voisi pitkän aikaa hyötyä sitä, että ilmoitukset on päällä. Jollain aikavälillä se aina...
# [48:21.470 --> 48:50.730]  Niin kuin just se kohinnan määrä lisääntyy, tavallaan tapahtumien määrä lisääntyy, ilmoitusten määrä lisääntyy, ja sitten siitä tulee silti hyödytöntä. Ja niin kuin jälleen, tämän takia mä oon valmis julistamaan, että ilmoituksien aika on ohi. Mutta sen sijaan, jos kysytte, että mitä tulee ilmoitusten jälkeen. Tässä kohtaa mä jotenkin alkaisin viittelödä hirveästi käsilläni, ja sanoin, että katsokaa, tuolla ulkona tapahtuu jotain, että kun mun mielestä semmoinen kontekstisidonnainen filteröinti ja tiivistäminenkin tuntuu vaan...
# [48:50.670 --> 49:16.130]  jonkin verran, jonkin asteen väliportaata. Siinä on selvästi, siinä on nähtävissä mahdollisia parannuksia, että nimenomaan, että pannaan kielimalli lukemaan nämä ja sitten suodattamaan ja filtterimaan, mutta esimerkiksi se nykyinen iOS-tapa, jossa on, että voi kieltää ilmoitukset, voi olla välittömästi toimitettavat ilmoitukset tai sitten ryhmitetyt, ja siihen voi määrätä, että montako kertaa päivässä mihin aikana ne ryhmitetyt ilmoitukset tulee läpi, niin en mä niin kuin...
# [49:16.360 --> 49:44.220]  Siinä on monta ongelmaa, joista eka on se, että ensinnäkin yleensä se pitää käytännössä päättää silloin, kun sovelluksen asentaa, tai sitten kun ekan kerran tulee se ilmoitus, niin pitää tavallaan silloin hahmottaa jo valmiiksi, että näin tämän pitäisi toimia. Ja mulla on nippu-ilmoituksia, jotka on siellä ajastetuissa, ja sitten aina kun mä näen sen, niin mä ajattelen, että no oikeastaan joko mä en tarvitse tätä ollenkaan, tai tämä ei saanut tulla heti läpi, mutta en mä jaksa enää navigoida sinne hemmetin asetuksiin siinä vaiheessa mennä vaihtamaan sitä, että periaatteessa ehkä se Applen lupailema fiksu.
# [49:44.880 --> 49:57.100]  laitteella toimiva jonkin sortin koneäly, ties mille hohtokytkimillä toimiva, voisi auttaa tässä, mutta kuten sanoin, minusta tämä tuntuu siitä, että tässä ei vain ratkota sitä itse ongelmaa.
# [50:36.430 --> 50:36.910]  Mm.
# [51:44.140 --> 51:44.840]  Mm-hmm.
# [52:55.080 --> 53:13.460]  Mitä siitä seuraa, kun Yle Areenassa otettiin ilmoitukset käyttöön? Haluaisitko Kari kertoa meille jotenkin yksityiskohdat pois viilattuna jotain tarinoita tästä? Posttraumaattinen stressireaktio, niin.
# [54:55.470 --> 55:19.910]  Siis, jos otetaan... Tai... Ja siis toi areena on myös sillä tavalla hyvä esimerkki, että kun on ollut tekemässä podcasteja, jotka kilpailee näkyvyydestä areenassa, ja totta kai halutaan paljon näkyvyyttä, koska se johtaa käynnistyksiä, ja sitten tilastot näyttää paremmalta, ja sitten tilaa ei ole sitä, että voidaan tilata lisää, niin se on nollasumma peli, ja aina on tietenkin itse varma siitä, että meidän ohjelma sai nyt vähemmän huomiota kuin muiden ohjelma.
# [01:06:15.680 --> 01:06:41.860]  Mä en silleen hahmota, että mikä homma se oli. Ja tietenkin myös se, että kun kävelet jossain ja sitten naputtelet kännykän ruudulla sitä, sitten lähetät sovelluksen sisältä. Se käynnistää sovelluksen sisällä selaimeen, johon on tosi helppo kirjoitella kaikki. Ja sitten se lähtee sähköpostiin varmistuskoodiin. Käyt hakemassa sen varmistuskoodi, joka avatuu selaimeen ja toivot, että sen rekisteröityi myös sovelluksen puolelle ja kirjoit uudestaan sisään. Ja totta kai tässä välissä tallesin salasanan, koska siis koska piti luoda tiliin, niin sille piti tehdä käyttäjätunnossa salasanan, niin olin tallennossa salasanamanageriin.
# [01:06:42.190 --> 01:07:08.870]  synkkäisen salasana managerasta takaisin ja pääsin sovellukseen kirjoitumaan sisään ja sain ostettua sen yhden lipun. Ehkä joku suomalainen voisi katantaa sinne jotain konsultaatiota näistä asioista, että kertaostoksen mielestäni voisi esimerkiksi tehdä kertaostoksena ilman, että tarvitsee rekisteröitä kauppaan. Se ei käy. Germaaniselle mieleenlaadulle oli johtopäätökseni. Kari, mitäs sinulla olisi meille vielä tarjolla tällä lukuvinkki tyyppisesti?
# [01:08:13.060 --> 01:08:40.560]  Hyvä, näin siirrymme vikasintotilan kesäaikaan, siis tosiaan tässä oli pieni tauko sen takia, että reissasin ja ajattelin, että siis vähän aikaa mietin, että olisi ollut tavallaan hauska läppä tehdä matkan päältä etääänityksenä jakson, mutta sitten katsoin puolisoani ja totesin, että jotenkin läppäkiintiö on jotenkin käytetty tässä nyt viime ajoilta, joten totesin, että ehkä vaan pidetään pieni tauko ja palataan asiaan, koska mikäs tässä podcastia?
# [01:08:40.940 --> 01:08:59.320]  Tehdään se, mutta siis ongelma on, että minua hikoiluttaa hirveästi, ja sitten minä en voi avata ikkunaa, koska sitten tulee mölyä. Nyt minä täällä kärsin, lähettäkää apua, jääpaloja ja muuta sellaista. Mutta teemme tässä varmaankin muutaman jakson kesän mittaan, ja näillä sanoilla sitten vaan seuraavaan kertaan. Paljon kiitoksia, ja heipudi, peipudi.
# [01:09:05.160 --> 01:09:17.220]  Otin löysin ranteen, enkä yhtään jännittänyt. Hyvä, kiitoksia. Laittakaa filettoa tulemaan vaan sitten. Se on moro. Heee. End for all.
# Transcription results written to '/content/drive/MyDrive/whisper/output/transcripts' directory
# Litteroidaan tiedostoa /content/drive/MyDrive/whisper/input/vst s10e06 - 2025-06-18 Files/audioPanuRaty317.wav
# Detected language 'Finnish' with probability 1.000000
# [03:16.680 --> 03:28.960]  Noniin, kuuluuko? Original sound for musicians on... sitten...
# [03:58.120 --> 04:00.340]  Mitä sinä sieltä oikein kaupustelet?
# [04:39.180 --> 04:43.900]  Hmm. Hmm. Hmm.
# [04:58.350 --> 04:59.170]  Kiitos.
# [05:38.960 --> 05:40.100]  Miesi smellin.
# [06:37.000 --> 06:38.780]  Mikäs tästä nyt on oleellista siis?
# [06:58.480 --> 06:59.140]  Hmm.
# [07:53.680 --> 07:54.260]  Kiitos.
# [09:29.770 --> 09:54.630]  Mä oon kolme näppäimistöä pöydällä. Kolme. Mä oon vähän näitä kun testailla, että mikä toimii. Mulla on myös Applein yksi näppäimistö pöydällä. Sitten mulla on tällainen ja sitten mulla on toi mekaaninen. Jää näistä nyt siihen.
# [10:41.770 --> 10:52.510]  Erityisen mä pidän mekaanista näppäimistä. Se on jotenkin, kun se havisee 80-luvulta, niin siellä on jotenkin miellyttävää kirjoittaa niillä 80-luvulla mekaanisilla näppäimistä.
# [11:03.310 --> 11:21.210]  Jotenkin miellyttävä se näppäin, se tuntuu joltakin se kirjoittaminen. Mutta saattaa olla itse asiassa, että joku tällainen, missä on ihan pieni se liikerata, niin kuin just jossain Apple, niin voi olla, että se on nopeampi itse asiassa.
# [12:19.120 --> 12:42.120]  Milloin sinun lomat alkaa? Joo, saa ääreipä sinun lomu. Joo. Joo.
# [12:50.060 --> 12:56.980]  Hmm, joo. Mä hypään jostain kuollossa. En tiedä vielä tarkkaa päivää, mutta jossain siinä vaiheessa.
# [13:00.970 --> 13:23.530]  Meillä on perinteinen, että mennään mökille viikoksi. Sitten hetki Helsingissä. Meillä on tällä hetkellä ollut kesäsi Suomi haltuun turneja. Eli eri paikkoja Suomessa. Nyt mennään tuonne Porin suuntaan ja sinne. Mä olen märkkänyt kuin lapsena jollakin työmatkoilla tapaamassa, jota Juha Seppälää siellä.
# [13:36.790 --> 13:43.430]  Tätä odotellessaan. Jotain sillä suunnalla.
# [13:59.600 --> 14:20.260]  Kaikki ongelmat ovat nyt ratkaistu, tai on nyt ratkaistu. Siitä emme puhuneet, kyllä. Tuo on aivan ihana näkökulma tähän aiheeseen.
# [14:25.740 --> 14:37.460]  No se on totta, täytyy määrää, että tavallaan kaikilla näillä sillä raskalaisporkalla oli kyllä jonkinlainen jättijäljen päähäni.
# [15:44.590 --> 15:45.250]  Hmm.
# [16:20.780 --> 16:38.220]  Joo, mä puhun nyt, vaikka tämä on ollut todella pitkään käytössä itselläni, mä otan protonmailin koko sen ekosysteemin. Mutta mä en ole siitä tainnut puhua koskaan. Mä en ole varma, mutta ainakin se ekosysteemi on laajentunut sen jälkeen aivan valtavaksi.
# [17:17.700 --> 17:20.720]  Olli Sulapuisto ei ole antanut meille oikeuksia muuten äänittää.
# [17:39.390 --> 17:41.290]  Nyt se lähti nauhoittamaan.
# [18:29.980 --> 18:32.920]  Panu räty, se on itseasiassa jäähdytin.
# [19:47.710 --> 19:51.010]  Sitä me emme hyväksy missään nimessä.
# [20:00.940 --> 20:02.260]  Korviin sattuu.
# [20:57.610 --> 20:58.250]  Kiitos.
# [23:55.340 --> 24:17.440]  Kyllähän noita voi jakaa useampaan kategoriaan, että ehkä ne kiusallisimmat on just sitä, että palvelu itse päättää, että meillä on tällainen uusi toiminnallisuus. Koska tästä emme ole sinulta mitään kysyneet, niin me alamme tästä vaan suoraan antaa sinulle näitä ilmoituksia. Mutta sitten onhan meillä tällaisia tyyliä, että jotain ikään kuin joku...
# [24:17.440 --> 24:45.760]  prosessi tai transaktio, tai kun tämmöinen tapahtuu, että paketti on toimitettu tai maksu on hoidettu. Tämmöistä on vielä sellainen, että tavallaan se ääristyskydys on tosi vähäinen. Tai sitten järjestelmästä tulevia notifikaatioita, että päivitäpä nyt se koneesi, niin kuin tämän tyyppisen, että päivitä se järjestelmä. Tällaisia toivookin, että hei, mua muistutetaan tekemään tämä. Mutta sitten nämä varsinaisesti ikään kuin...
# [24:48.290 --> 25:13.650]  sovellusten käyttäjälle antamat notifikaatiot jostain, niin kuin hei, meillä on tällainen, tavallaan tämä tili ilmoittaa sinun jotakin, ja tänne on tullut tämä ryhmä, uusia viestejä, tai olet saanut tätä ja tätä, olet saanut tällaisen tarjouksen. Nämähän tuottaa sitä, ne alkaa tultua välittömästi sellaista roskapostilta. Ja vaikka ne saattaa, niin kuin mä oon itse huomannut ihan arjessa sen, että ne saattaa
# [25:14.260 --> 25:30.360]  tuottaa tämän saman efektin, vaikka olisin itse ne tietoisesti tilannut. Mä olen halunnut, että tämä on kiinnostava asia, tätä haluan seurata, mutta jumalauta, sitten kun se tulee se ilmoitus, että puhelimeen se keskeyttää kaiken, niin se ei niin kuin...
# [25:46.730 --> 25:47.390]  Kiitos.
# [30:53.610 --> 31:20.130]  Mä tuossa vähän silmäillin taustoja, niin mä kiinnitän vaan huomiota, että useammassa nää lähteessä mainittiin, että esimerkiksi keskimääräinen amerikkalainen saisi jonkun 40-50 notifikaatioita päivässä. Mä en tiedä pitääkö se paikkansa, ja mä luulen, että ne voi olla vanhentunutta tietoa, ja sitä paitsi mä oletan, että se on käyttäjäkunnassa riippuvainen, että se on, kun mennään vähän nuorempiin käyttäjäkuntiin, varmaan tulee enemmän. Tämä on ainakin se mun oletus.
# [31:28.910 --> 31:38.490]  Ja, ja, ja. Ja.
# [33:06.290 --> 33:33.970]  Niin, tismalleen näin, mutta käytännössä, koska niitä viestejä voi tulla aika paljon välillä, niin huomaan itsekin tekeväni niin, että kun pitää keskittyä, niin kaikki viestit on pois ja kaikki notifikaatiot on pyyhitty näkymättömistä. Ja mä en näe, saattaa mennä kokonainen päivä, että mä en näe yhtään ainutta, koska jos on semmoinen päivä, että pitää keskittyä, niin silloin ne on tavallaan sitten niitä blokkeja, ikään kuin tekee semmoisia ajallisia blokkeja, että kello 16.
# [33:34.650 --> 33:52.050]  aukeaa puhelin ja sitten käyn niitä läpi. Sen jälkeen tulee myös viestejä niistä omista sovelluksia, jotka lähettävät viestejä, että muistapa tehdä tämä tai muistapa. Tällaisia arkisiin rutiineihin liittyviä tai harrastuksiin liittyviä asioita.
# [34:13.450 --> 34:15.750]  Olenko minä nyt barbaari, Kari?
# [35:57.320 --> 36:00.520]  Niin ei accepte...
# [36:43.820 --> 36:44.280]  Hmm.
# [36:56.360 --> 37:25.400]  Niin siis tämmöiset järjestelmät tarvitsis jonkinlaisen tavan priorisoida niitä viestejä. Niin kuin Kari sanoi, jonkinlainen kohdentaminen ja personointi, että sitä pystyttäisiin, että se järjestelmä oppisi tunnistamaan ne ikään kuin, voisiko sanoa, tärkeimmät notifikaatiot. Että näistä tarvitaan läpimenevä viesti, vaikka se laite olisi, vaikka olisin sulkenut sen laitteen, että tämä pitää mennä läpi joka tapauksessa. Kun taas tämmöistä...
# [37:25.530 --> 37:34.210]  vähän vähemmän tärkeintä, niin sitten ne voi viivästyä siihen asti, kun mä ihan aidosti avaan sen laitteen ja nyt minä haluan katsoa, mitä on tapahtunut.
# [39:55.980 --> 39:56.580]  Hmm.
# [40:30.000 --> 40:32.420]  Pitäpua. Kyllä. Kyllä.
# [40:47.240 --> 41:15.080]  Mutta se on ihan totta, että tähän tarvitsisi jonkinlaista semmoista kurhatoivaa, oppivaa, äärimmäisen jotenkin kontekstitietoista järjestelmää, joka jotenkin osaisi huomioida sekä käyttäjän tilanteen, sen ympäristön, missä se on, ajankohdan, sen toiminnan, mitä se kulloinkin tekee. Että tavallaan se kontekstitietoisuus, jotta se oikeasti voisi toimia, niin pitäisi huomioida ihan paljon erilaisia muuttujia.
# [41:15.400 --> 41:29.600]  samanaikaisesti, jotta se pystyisi tuottaa jonkinlaisen yksilöllisen suodatuksen, joka hyödyntää sen nimenomaisen käyttäjän toimintaa kulloisessakin tilanteessa.
# [42:45.130 --> 42:46.970]  Ha ha ha ha ha.
# [44:33.100 --> 44:54.020]  Ha ha ha ha ha. Ha ha ha ha ha.
# [46:57.870 --> 46:58.410]  Hmm.
# [47:43.240 --> 47:44.020]  Kiitos.
# [49:19.020 --> 49:19.472]  Kiitos.
# [50:56.910 --> 51:26.290]  Niin mä luulen, että siellä on tavallaan jotenkin paradoksaalista. Se varmaan toimii niin, että jos mä nään vähemmän notifikaatioita, joista mä oletan olevan itselleni enemmän arvoa, niin silloin mun suhde siihen notifikaation on suuremmin se, että mä avaan ne. Ja silloin mä vilkasen, että mitä siellä oikeasti on. Mutta jos mä joudun siihen tulvaan, niin sit mä laitan kaiken pois. Sitten mä löydän rauhan.
# [57:34.250 --> 57:36.490]  Ha ha ha ha ha ha.
# [59:31.280 --> 59:32.080]  Yho!
# [01:00:06.870 --> 01:00:08.110]  Olemme valmiita kyllä.
# ...
# [16:33.110 --> 16:35.030]  Mä ajattelin, että...
# [16:39.280 --> 16:59.120]  Mä ajattelin, että mä suosittelen New York Timesin semmoista vertailu, tai ei se oo vertailu, se on vinkkijuttu, lautapeleistä, joita voi pelata kahdestaan. Koska se on... Jumalauta! Tu pois sieltä! Pois pois!
# [17:02.040 --> 17:23.740]  Tiskiallas, koska Ester on, en oikein tiedä mikä sillä on, mutta hän syö kaiken. Siis aivan kaiken, mikä tulee vastaan. Jos on sattunut jäämään Lautanen, jossa on kaksi riisiä. Kato, kato, kato.
# [17:43.530 --> 17:49.030]  Request to record this computer. Send request.
# [18:24.620 --> 18:35.580]  Kari Haakana, mene Ester pois. Siitä mene mene. Kenet se jäähdyttää?
# [19:21.970 --> 19:27.290]  Notsku. Jumalauta ei. Niin.
# [19:54.320 --> 19:57.280]  Mä oon alkanut hyväksymään tota...
# [20:56.230 --> 20:57.770]  Sinun tuli ilmoitu sen.
# [21:44.940 --> 22:11.220]  No mulla hiertää ehkä kaikkein eniten, siis ilmoituksiahan on monenlaisia, sehän riippuu vähän siitä softasta tai palvelusta, että millä tavalla ne on toteutettu, mutta itseäni hiertää kaikkein eniten notifikaatit, jotka ei ole selkeästi hallittavissa. Siis että softa tai palvelu alkaa yhtäkkiä lähettää notifikaatit, elikäs ilmoituksia.
# [22:11.720 --> 22:36.980]  Ja mulla on epäselvää, miksi saan tämän ilmoituksen ja mitä olen tehnyt väärin saadakseni tämän ilmoituksen. Mun on tästä pari esimerkkiä. Viimeisimpien viikkojen aikana Reddit on alkanut lähettää mulle ilmoituksen. Ja mä en muista, että olisin kytkenyt ilmoitukset ja saan niitä oudoista aiheista, jotka ei mun mielestä osu.
# [22:37.240 --> 23:04.360]  osun minun intresseihin, niin tulee melkein säännönmukaisesti kerran päivässä ja se on aina vähän samaan suuntaan oleva aihe. En nyt käy avaamaan tässä sitä aihetta, koska haluan olla mysteerimies, ei ollut taankin, mutta se on hämärää. Toinen esimerkki oli kollegalta, joka ihmetteli työpaikan
# [23:05.500 --> 23:34.400]  yhdessä chattiryhmässä, että minkä takia hän saa ilmoituksia Google Discoverista. Eli hän oli saanut, jos muistan oikein, niin iOS-puhelimeensa Googlelta ilmoituksen siitä, että Iltalehdellä on otsikko, joka kuuluu näin. Ja sekin oli sellainen, että en ole tilannut tällaista ilmoitusta, miksi Google lähettää tämä, miten tämä liittyy.
# [23:34.270 --> 23:54.170]  ja näitä molemmissa yhdistävänä tekijänä on se, että se ilmoitus on jotenkin hämärä tai sen muodostamismekanismi tai tilausmekanismi tai se, että miksi se on räätälöity juuri minulle, niin se ainakin minulla on yksi keskeinen syy.
# [25:26.000 --> 25:34.860]  Ha, ha, ha, ha. Ha, ha, ha.
# [26:59.680 --> 27:24.860]  Minusta on selvää, että siinä alkuvaiheessa, kun ilmoitukset olivat uusi asia, niin kaikki sovelluksen tekijät pyrkivät tietenkin maksimoimaan sitä, että nyt meillä on keino, jolla me saadaan käyttäjän huomio, ja sitä pitää käyttää tosiaan maksimaalisesti, että saadaan mahdollisimman paljon käyttäjää
# [27:27.030 --> 27:55.050]  huomiota sille sovellukselle, koska kaikki tutkimukset osoittivat, että ihmiset käyttävät vain muutamaa sovellusta päivässä, ja se älypuhelimen käynnistysruutu on se paikka, josta siinä vaiheessa kilpailtiin ja ajateltiin, että pääseminen siihen aloitusruudulle, siihen ensimmäiseen näkymään on se, mikä täytyy saada, jos mieli saada käyttäjää asiakkaikseen, ja notifikaatiot tai ilmoitukset nähtiin keskeisenä.
# [27:55.420 --> 28:20.960]  keinona sitten kamppailla myöskin huomiosta, mutta sitten tosiaan homma ryöstäytyi käsistä, ja mun mielestä jotenkin oireellista on se, että mä en tunne IOSa niin hyvin, koska mä oon käyttänyt oikeastaan melkein koko älypuhelinajan Androidia, mutta Android on koko ajan sen jälkeen, kun ilmoitukset tuotiin, niin viilannut sitä ilmoitusten
# [28:21.560 --> 28:43.000]  ikään kuin ilmestymistä ja keinoja ikään kuin rajoittaa niitä ja nyt uusimmassa Android 16 on siis tämmöinen ominaisuus, josta alkaa ikään kuin stäkätä niitä ilmoituksia, eli jos jostakin sovelluksessa niitä tulee paljon, ne ryhmitellään ikään kuin yhdeksi kokonaisuudeksi, että ne ei enää näykään yksittäisenä ilmoituksenaan.
# [28:56.910 --> 28:57.650]  Kiitos.
# [31:03.630 --> 31:08.830]  Mitä juomala? Bing bing bing.
# [31:53.660 --> 31:55.060]  Siis...
# [31:58.860 --> 32:23.440]  Siis oikeastaan ainut poikkeus on just toi WhatsApp kautta Signal-tyyppinen viestintä, jossa on todennäköisempää, että sun pitää jollakin tavalla reagoida siihen. Että se ei ole yksipuolista push-viestintää, vaan se on jossakin määrin oletettavasti interaktiivista.
# [32:25.480 --> 32:31.840]  Muista tuoda lääkkeet tyyppinen asia, joka olisi hyvä ehkä muistaa. Minun pitäisi oikeasti viedä lääkkeet.
# [33:52.700 --> 34:13.960]  Mun mielestä tavallaan just se, että nämä puhelinalustot on alkaneet kehittää tämmöisiä, blokkaa kaikki ilmoitukset tyyppisiä toiminnallisuuksia, niin kertoo siitä, että se on rikki. Ja sitten se, että joudun kuin barbaari blokkaamaan kaikki ilmoitukset, ja että siellä ei ole minkään...
# [34:15.910 --> 34:43.430]  Kyllä mun mielestä ihminen, jota puhutellaan ja joka ei vastaa puhutteluun, niin lähtökohtaisesti on barbaari. Tietysti liittyy vähän siitä, riippuu siitä, että kuka puhuttelee ja millä tavalla, mutta ratkaisu nyt kaiken järjen mukaan pitäisi olla jonkinlainen älykkyys, eli se, että laite tai käyttöjärjestelmä oppisi aika nopeasti, siis muutamassa päivässä tai maksimissaan muutamassa viikossa ymmärtämään, että
# [34:43.920 --> 35:06.980]  että puolisolta tuleva WhatsApp-viesti on semmoinen, joka on suhteellisen kriittinen. Lapsilta tulevat viestit voi olla kriittisiä, paitsi ei ole, jos se sisältää esimerkiksi viestisanan peli, tai että esimerkiksi pankilta tuleva viesti saattaa olla kriittinen, riippuen siitä, mitä siinä pankissa tulevassa viestissä on.
# [35:57.560 --> 36:17.020]  Olli, tervetuloa kurssilleni. Näin priorisoit, koska selvästikään sä et osaa priorisoida. Mutta mä vastaan vaan siihen, että mun mielestä keskeinen ongelma on se, että Androidin ja iOSn kaltaiset, sanotaan, että vaikka toimijat, ei aidosti ole siis sen asiakkaan ja sen...
# [36:16.920 --> 36:45.260]  käyttäjän intresseistä kiinnostuneita tai ne ei ole ikään kuin käyttäjän puolella, koska ne ei kehitä tämän kaltaisia toiminnallisuuksia, jotka aidosti ikään kuin oppisivat ymmärtämään, mikä sille käyttäjälle on tärkeetä. Ja niinkaan kuin näin on, niin kaikki, jotka niitä viestejä lähettää, niin ikään kuin geimaa sitä systeemiä. Mutta sen systeemin pitäisi olla parempi. Eli siis Applenia... Niin, Applenia...
# [36:45.480 --> 37:13.600]  Applein ja Googlen pitäisi toimia fiksummin, mutta niillä ei ole minkäänlaista, tai näin mä tulkitsen, että niillä ei ole minkäänlaista taloudellista insentiiviä toimia tässä käyttäjän puolesta järkevästi. Just niin.
# [37:20.040 --> 37:20.600]  Hmm.
# [38:14.730 --> 38:15.330]  Kiitos.
# [38:34.150 --> 39:01.850]  Niin, minä luulen, että tässä me törmätään jälleen kerran siihen, että tämä priorisointi on ensinnäkin hyvin kulttuurisydonnaista, siis se, että Kaliforniassa prioriteetit vaan yksinkertaisesti on erilaisia kuin täällä Vallilassa, ja sitten se on myös henkilökohtaisesti erilaista, että sen takia varmaan sellaisen älykkään priorisoinnin
# [39:02.410 --> 39:28.090]  kehittäminen on vaikeata, koska niitä muuttujia on niin paljon, ja itse esimerkiksi käyttäjänä saatan olla torstaina eri mieltä siitä, että mikä se relevantti priorisointi olisi. Kiinteä ja lämmin.
# [39:31.530 --> 39:32.690]  Hehehehe.
# [40:32.610 --> 40:46.190]  Joogaläppärini kertoo minulle juuri nyt, että minun pitäisi olla Asanassa. Mä tiedän, koska se taipuu erilaisiin asentoihin.
# [41:36.200 --> 41:37.600]  Tal.
# [42:14.510 --> 42:42.210]  Niin, sen automaation pitäisi olla jotenkin jatkuvasti korjaava tai sen pitäisi jotenkin kysellä ilmeisesti aika pitkään. Että näyttää siltä, että sulla on kalenterissa merkitty, että sä oot kokouksessa, mutta paikkatieto kertoo, että sä oot kotona, joten mä päättelen, että tää sun kokous on etäkokousi, koska tää näyttää sellaiselta kokoukselta, jonka aikana sä oot viimeiset...
# [42:42.120 --> 43:10.980]  kolme kertaa lähinnä ollut Onlyfansissä, niin päättelin, että tämän kokouksen aikana voin lähettää sinulle viestin. Oliko oikeassa, Kari? Niin, juuri näin. Jep.
# [44:41.930 --> 44:54.110]  That would be me. Niin tai sit ne voi vaan etsiä sillä etsimistointoja.
# [44:54.280 --> 45:19.960]  Toiminnolla. Mutta mä tunnistan, kun tämä saattaa olla jonkinlainen luonnekysymys tai muuta, mutta kyllä mä toimin suurimman osan ilmoituksia kanssa just noin. Sitten niitä vaan tulee sieltä, ja kaikkein pahin tässä on mun mielestä New York Times, joka lähettää paitsi Breaking News-ilmoituksia, ja ne Breaking News on silleen, uuu, Etelä-Karolainassa koirasöimaisia tyyppisiä.
# [45:20.320 --> 45:45.100]  ilmoituksia ja sitten jonkinlaisia voisit ehkä pitää tästä ilmoituksia. Ja sitten mä en ole vieläkään pystynyt selvittämään, että miten mä saisin pankkikortistani pois sen ominaisuuden, että se lähettää mulle notifikaatin. Anteeksi, ilmoituksia joka kerta, kun mä ostan pankkikortilla jotain, niin sieltä tulee. Kari on ostanut Onlyfanssiä taas täällä.
# [46:26.940 --> 46:30.440]  S-mobiili, only fancy suomalainen versio.
# [49:20.650 --> 49:21.470]  Motta.
# [49:27.560 --> 49:55.000]  Mun mielestä tämä on, jos käyttää tätä kollegan Google Discover-ilmoitusta ikään kuin esimerkkinä, niin tavallaan viitteitä on vähän siitä, että se vaan ikään kuin leviää, tai se Reddit-ilmoitukset, joita mä saan, että ilmeisesti sieltä nyt kuitenkin analytiikasta näkyy, että näillä
# [49:55.280 --> 50:23.540]  näillä ilmoituksilla on jotain vaikutusta, ja sitä kannattaa kokeilla. Ehkä se vaikutus on sen kaltainen, että roskapostilla tai huijaussähköpostilla, että koska tämä ei nyt maksa ihan kauheasti, niin näitä kannattaa lähetellä, ja aina sieltä joku torvi tähän tarttuu, ja sitten saadaan hynkkää. Mä oon vähän pessimistinen sen suhteen, ja se ainut keino, joka siinä oikeastaan...
# [50:23.600 --> 50:52.220]  että se alusta jollakin tavalla ottaisi enemmän vastuuta niistä ilmoituksista ja niiden relevanssista. Tai että tulee jokin välikerros, jonka avulla mä pystyn jotenkin aktiivisesti hallinnoimaan sitä ilmoitusten tulvaa, että se on jonkinlainen henkilökohtainen assistentti tai jonkinlainen agentti, joka haravoi niitä. Ei toi niitä edes mulle näkyviin, vaan jotenkin...
# [50:52.430 --> 50:56.750]  tai tuo niitä näkyviin hyvin harkitusti.
# [51:26.630 --> 51:42.410]  Sitten vielä tietysti on ehkä kahdenlaisia ilmoituksia. Tyypillisesti varmaan uutispalveluiden ilmoitukset ovat sellaisia, jotka ovat skimmattavissa. Mulle tulee ilmoitus jostain...
# [51:43.540 --> 52:11.740]  uutisesta, että Yhdysvaltain presidentti on taas syönyt paskaa. Se on sellainen, että okei, se informaatio välittyy nyt tässä ilmoituksessa ja se ei vaadi minulta sen suurempaa toimintaa. Sitten on ilmoituksia, joiden informaatio tai arvo on oikeastaan se, että klikkaan siitä ilmoituksesta eteenpäin tekemään jotakin. Esimerkiksi työpaikan ryhmä
# [52:11.900 --> 52:24.960]  chatissa Tauno on taas sanonut jotain, joka ei pidä paikkaansa, että täytyy mennä pelastamaan softa hajoamiselta, koska Tauno on tehnyt pull requestin ja kaikki tiedämme, mitä siitä seuraa.
# [52:34.880 --> 52:59.780]  Tuossa aikaisemmin oli jotain puhetta, stressi, mikä se on posttraumaattinen, niin ehkä se on pyyhkinyt muistijäljittäistä, mutta muistan, että kun ilmoitukset alkoivat ikään kuin tulla, että oli mahdollista lähettää ilmoituksia, niin ne tuotiin Yle Areenaan.
# [53:01.800 --> 53:29.600]  Kyllä muistan, että keskusteltiin aika paljon siitä, että se relevanssi sille käyttäjälle oli tosi tärkeää. Kukaan ei halunnut, että ryhdytään lähettämään ensinnäkään tosi paljon suurta määrää ilmoituksia ja sitten, että millä perusteella niitä ilmoituksia ikään kuin lähetettiin. Siellähän on...
# [53:29.450 --> 53:52.290]  Tällä hetkellä suurin osa Areena-ilmoituksista on niitä, että käyttäjä on merkinnyt ohjelman suosikikseen ja saa ilmoituksen siitä, kun uusi jakso esimerkiksi on ilmestynyt. Mutta sitten on tavallaan tällaisia ilmoituksia, jotka tulee sen takia, että käyttäjä, joka kuuluu johonkin demografiseen ryhmään, niin katsotaan, että tämä...
# [53:53.680 --> 54:21.860]  Aupairit Thaimaassa sopii minulle, koska olen yli 50-vuotias mies ja sen takia siitä tulee sinulle ilmoitus. Mutta esimerkiksi se, että sellainen tilanne, jossa lähetetään ilmoitus kaikille käyttäjille, on äärimmäisen harvinainen ja niitä on lähinnä sellaiset olympialaisten avajaiset tai todella merkittävä TVn ylimääräinen uutislähetys. Nämä ovat sellaisia, joista...
# [54:21.710 --> 54:25.310]  Lähetetään ja tämä periaate on mun mielestä ollut alusta saakka käytössä.
# [55:08.480 --> 55:29.660]  Niin, ja ainakin jossakin vaiheessa se, että ohjelmassa tai ohjelman lopussa kehotetaan merkkaamaan suosikiksi, oli ainakin osittain myöskin käyttäjien ikään kuin informointia siitä, että tämmöinen ominaisuus sovelluksessa on, koska ei se ole käyttäjille myöskään mitenkään itsestään selvää, että he pystyvät saamaan tämmöisen ilmoitun.
# [55:37.640 --> 55:38.420]  Alaa!
# [56:32.690 --> 56:52.590]  Se johtuu siitä, että se Facebookin sivutiimi saa jonkun pöynyksen, jos ne pystyy aktivoimaan siellä käyttäjä, ja niillä on joku kiintiö ilmoituksiin, joita ne lähettää käyttäjä. Joku täysin irrelevantti käyttäjän näkökulmasta säätö.
# [57:06.570 --> 57:07.130]  Kiitos.
# [57:21.480 --> 57:44.840]  Ja mun ehdoton suosikki, josta mä oon saanut palautetta ihmisiltä, on, että minkä tun takia Facebook näyttää mulle ilmoituksi joka kerta, kun haakana postaa jotain. Niin kuin että, no, soita Zuckerbergille, en minä tiedä. Mutta mä ymmärrän sen, että siinäkin taustalla on siis varmaan se, että...
# [57:46.220 --> 58:06.300]  Kyseinen ihminen on kommentoinut tarpeeksi monta kertaa, jolloin Zuckerberg päättelee, että sinulle pitäisi nyt varmaan vinkata joka kerta, kun Karilla on jotain viisasta asiaa siellä Facebookissa. Joo.
# [01:00:05.960 --> 01:00:07.100]  Olemme valmiita.
# [01:00:39.630 --> 01:00:40.810]  Hehehehe.
# [01:03:53.960 --> 01:04:14.300]  Mä oon aivan varma, että ProtonMail on CIA-operaatio. Tällä tavalla saadaan kaikki hakkerit käyttämään tämmöstä todella luotetta, tämä sveitsiläinen ohjelma ja palvelu, ja sitten siellä CIA lukee niitä kaikkia viestejä kaikki illat.
# [01:04:21.260 --> 01:04:25.280]  CIA on kolme kirjainta, kuten VPN. Tämä todistaa pointtini.
# [01:05:29.840 --> 01:05:29.840]  Kiitos.
# [01:06:39.020 --> 01:07:05.940]  No, minä suosittelen New York Timesin Wirecutter-palvelun juttua, johon on kerätty, hetkinen, kuinka monta niitä olikaan, oliko niitä kahdeksan peliä, siis lautapeliä, joita voi pelata kahden ihmisen kesken. Lautapelithan on kivoja, mutta aika monessa lautapeliä...
# [01:07:05.770 --> 01:07:30.750]  Pelissä se pelimekaniikka on sellainen, että se oikeastaan vaatii useamman kuin kaksi pelaajaa, tai sitten tulee mielenkiintoisempaa, kun niitä pelaajia on enemmän kuin kaksi. Tässä tapauksessa on nimenomaan lautapelejä, jotka toimivat kahden ihmisen kesken. Koska kesä on käsillä ja kesä on laitapelien aukkaan,
# [01:07:30.750 --> 01:07:40.770]  koska ulkona sataa vettä ja ei sinne voi mennä, niin tämä on hyvä vinkkijuttu, löytyy show notesista.
# [01:08:01.100 --> 01:08:02.460]  Läppä ei ole vaan toiminut.
# [01:08:31.960 --> 01:08:40.260]  Hei hei Kiitos täällä
# Transcription results written to '/content/drive/MyDrive/whisper/output/transcripts' directory
# Lisätään tekstitys 'audioKariHaakana3.json' tiedostoon 'vst s10e06 - 2025-06-18 litteroitu.nhsx'
# Lisätään tekstitys 'audioKariHaakana2.json' tiedostoon 'vst s10e06 - 2025-06-18 litteroitu.nhsx'
# Lisätään tekstitys 'Olli.json' tiedostoon 'vst s10e06 - 2025-06-18 litteroitu.nhsx'
# Lisätään tekstitys 'audioPanuRaty311.json' tiedostoon 'vst s10e06 - 2025-06-18 litteroitu.nhsx'
# Lisätään tekstitys 'audioPanuRaty317.json' tiedostoon 'vst s10e06 - 2025-06-18 litteroitu.nhsx'
#
# Valmista tuli.
